# %%
item1=1200
item2=800
item3=600
discount=0.1
total=item1+item2+item3
final_bill=total-(total*discount)
print("total bill:",total)
print("final bill after discount:",final_bill)
gst=0.18
gst_rate=gst*final_bill
print("after gst:",gst_rate)
total_price=final_bill+gst_rate
print("total price:",total_price)
# Out:
# total bill: 2600
# final bill after discount: 2340.0
# after gst: 421.2
# total price: 2761.2

# %%
marks=int(input("enter your score:"))
if marks>=95:
  print("Grade A+(outstanding!)")
elif marks>=85:
  print("Grade A(excellant)")
elif marks>=75:
  print("Grade B (good)")
elif marks>=60:
  print("Grade C (average)")
else:
  print("Grade D (needs improvement)")
# Out:
# enter your score:54
# Grade D (needs improvement)

# %%
customers=["rahul","priya","amit","sneha","vikram"]
for name in customers:
  print("Sending emails to:",name)
# Out:
# Sending emails to: rahul
# Sending emails to: priya
# Sending emails to: amit
# Sending emails to: sneha
# Sending emails to: vikram

# %%
students={"rahul":85,"priya":92,"amit":74}
for name,marks in students.items():
  if marks>=90:
    grade="A"
  elif marks>=75:
    grade="B"
  else:
    grade="C"
   print(f"Student:{name},Marks:{marks},Grade:{grade}")
# Out:
# Student:rahul,Marks:85,Grade:B
# Student:priya,Marks:92,Grade:A
# Student:amit,Marks:74,Grade:C

# %%
def eligiblity(age):
  print(age)
  if age>=18:
    print("ELIGIBLE FOR VOTING")
  else:
    print("NOT ELIGIBLE FOR VOTING")
eligiblity(19)
eligiblity(17)
# Out:
# 19
# ELIGIBLE FOR VOTING
# 17
# NOT ELIGIBLE FOR VOTING

# %%
import math
print("square root of 25:",math.sqrt(25))
print("value of pi:",math.pi)
# Out:
# square root of 25: 5.0
# value of pi: 3.141592653589793

# %%
for i in range(1,6):
  print("reminder email no.:",i)
# Out:
# reminder email no.: 1
# reminder email no.: 2
# reminder email no.: 3
# reminder email no.: 4
# reminder email no.: 5

# %%
def issue_books(student_name,books):
  print(f"\n {student_name} borrowed:")
  for book in books:
    print("-",book)

def calculate_fine(days_late):
  fine_per_day=5
  return days_late*fine_per_day

def student_report(student_name,books,days_late):
  issue_books(student_name,books)
  fine=calculate_fine(days_late)
  print(f"Fine to be paid:{fine}\n")

student_report("Rahul",["python basics","data science 101"],3)
student_report("priya",["machine learning"],0)
# Out:
#  Rahul borrowed:
# - python basics
# - data science 101
# Fine to be paid:15
#
#
#  priya borrowed:
# - machine learning
# Fine to be paid:0
